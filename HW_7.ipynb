# %% [markdown]
# <a href="https://colab.research.google.com/github/bam396/nyu-python-public-policy/blob/master/HW_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **HW 7: Final Assignment**
# # Data Sources
# **311 Complaints Data**
#
# *   File path on google drive: '/content/drive/My Drive/Data for Python/cleaned_311_data_revised.csv'
#
# **Community District Profiles**
# * [Data Dictionary](https://communityprofiles.planning.nyc.gov/data/cd_profile_data_dictionary.csv)
# * [Indicators data](https://planninglabs.carto.com/api/v2/sql?format=csv&q=SELECT%20cartodb_id,the_geom,the_geom_webmercator,acres,acs_tooltip,acs_tooltip_2,acs_tooltip_3,area_sqmi,borocd,cb_email,cb_website,cd_full_title,cd_short_title,cd_son_fy2018,cd_tot_bldgs,cd_tot_resunits,count_hosp_clinic,count_libraries,count_parks,count_public_schools,crime_count,crime_count_boro,crime_count_nyc,crime_per_1000,crime_per_1000_boro,crime_per_1000_nyc,female_10_14,female_15_19,female_20_24,female_25_29,female_30_34,female_35_39,female_40_44,female_45_49,female_5_9,female_50_54,female_55_59,female_60_64,female_65_69,female_70_74,female_75_79,female_80_84,female_85_over,female_under_5,fp_100_area,fp_100_bldg,fp_100_cost_burden,fp_100_cost_burden_value,fp_100_mhhi,fp_100_mortg_value,fp_100_openspace,fp_100_ownerocc,fp_100_ownerocc_value,fp_100_permortg,fp_100_pop,fp_100_rent_burden,fp_100_rent_burden_value,fp_100_resunits,fp_500_area,fp_500_bldg,fp_500_cost_burden,fp_500_cost_burden_value,fp_500_mhhi,fp_500_mortg_value,fp_500_openspace,fp_500_ownerocc,fp_500_ownerocc_value,fp_500_permortg,fp_500_pop,fp_500_rent_burden,fp_500_rent_burden_value,fp_500_resunits,lep_rate,lep_rate_boro,lep_rate_nyc,lot_area_commercial_office,lot_area_industrial_manufacturing,lot_area_mixed_use,lot_area_open_space,lot_area_other_no_data,lot_area_parking,lot_area_public_facility_institution,lot_area_res_1_2_family_bldg,lot_area_res_multifamily_elevator,lot_area_res_multifamily_walkup,lot_area_transportation_utility,lot_area_vacant,lots_commercial_office,lots_industrial_manufacturing,lots_mixed_use,lots_open_space,lots_other_no_data,lots_parking,lots_public_facility_institution,lots_res_1_2_family_bldg,lots_res_multifamily_elevator,lots_res_multifamily_walkup,lots_total,lots_transportation_utility,lots_vacant,male_10_14,male_15_19,male_20_24,male_25_29,male_30_34,male_35_39,male_40_44,male_45_49,male_5_9,male_50_54,male_55_59,male_60_64,male_65_69,male_70_74,male_75_79,male_80_84,male_85_over,male_under_5,mean_commute,mean_commute_boro,mean_commute_nyc,moe_bach_deg,moe_bach_deg_boro,moe_bach_deg_nyc,moe_foreign_born,moe_hh_rent_burd,moe_hh_rent_burd_boro,moe_hh_rent_burd_nyc,moe_lep_rate,moe_lep_rate_boro,moe_lep_rate_nyc,moe_mean_commute,moe_mean_commute_boro,moe_mean_commute_nyc,moe_over65_rate,moe_over65_rate_boro,moe_over65_rate_nyc,moe_poverty_rate,moe_under18_rate,moe_under18_rate_boro,moe_under18_rate_nyc,moe_unemnployment,moe_unemployment_boro,moe_unemployment_cd,neighborhoods,over65_rate,over65_rate_boro,over65_rate_nyc,pct_asian_nh,pct_bach_deg,pct_bach_deg_boro,pct_bach_deg_nyc,pct_black_nh,pct_clean_strts,pct_clean_strts_boro,pct_clean_strts_nyc,pct_foreign_born,pct_hh_rent_burd,pct_hh_rent_burd_boro,pct_hh_rent_burd_nyc,pct_hispanic,pct_other_nh,pct_served_parks,pct_white_nh,pop_2000,pop_2010,pop_acs,pop_change_00_10,poverty_rate,poverty_rate_boro,poverty_rate_nyc,puma,shared_puma,shared_puma_cd,son_issue_1,son_issue_2,son_issue_3,total_lot_area,under18_rate,under18_rate_boro,under18_rate_nyc,unemployment_boro,unemployment_cd,unemployment_nyc%20FROM%20community_district_profiles&filename=indicators.csv)
# * [Floodplain indicators data](https://planninglabs.carto.com/api/v2/sql?format=csv&q=SELECT%20*%20FROM%20cd_floodplains_v201902&filename=cd_floodplains_v201902.csv) (not covered in the data dictionary but I'm happy to help you track down the right fields to use)
#
# # Problem Statement:
# 311 data is an incredible resource, but one major concern with 311 complaints is that there can be bias in the data. The fact that one community district has a higher number of 311 noise complaints, doesn't necessarily mean it is actually louder than another community district. It simply means more people submitted 311 complaints. Some neighborhoods may have residents that are more likely to submit complaints than others for various reasons (ex: different expectations, more awareness about 311, more free time, more sense of empowerment or hope that the complaint will be resolved, etc). This makes it difficult to get a clear picture of conditions across the city, and it can help to compare datasets against each other.
#
# Community District Profiles is an application that provides objective statistics about community districts. In this assignment, you will chose an indicator published on Community District Profiles and compare it against 311 complaint data.
#
# **Some ideas for inspiration:**
#
# * How does the number of buildings in the floodplain correlate with the number of 311 flooding complaints?
# * How does the street cleanliness score correlate with 311 complaints about garbage and cleanliness?
# * How does the percent of residents living in rent burden correlate with a number of 311 housing complaints (no heat/hot water or unsanitary conditions)?
#
# **Note:** This is a more open ended assignment where you can dig into policy concerns that are of greatest interest to you. If the results of your analysis are inconclusive, that is okay, as long as you are using proper python coding techniques. You will be graded on approach and methodology, rather than the outcome of the analysis.
#
#
# ---

# %% [markdown]
# # Step 0. (data prep)

# %%
import pandas as pd
import numpy as np
from google.colab import drive
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# 311 data
df = pd.read_csv('/content/drive/My Drive/Data for Python/cleaned_311_data_revised.csv', header='infer')
# community district indicator data
cddf = pd.read_csv('https://planninglabs.carto.com/api/v2/sql?format=csv&q=SELECT%20cartodb_id,the_geom,the_geom_webmercator,acres,acs_tooltip,acs_tooltip_2,acs_tooltip_3,area_sqmi,borocd,cb_email,cb_website,cd_full_title,cd_short_title,cd_son_fy2018,cd_tot_bldgs,cd_tot_resunits,count_hosp_clinic,count_libraries,count_parks,count_public_schools,crime_count,crime_count_boro,crime_count_nyc,crime_per_1000,crime_per_1000_boro,crime_per_1000_nyc,female_10_14,female_15_19,female_20_24,female_25_29,female_30_34,female_35_39,female_40_44,female_45_49,female_5_9,female_50_54,female_55_59,female_60_64,female_65_69,female_70_74,female_75_79,female_80_84,female_85_over,female_under_5,fp_100_area,fp_100_bldg,fp_100_cost_burden,fp_100_cost_burden_value,fp_100_mhhi,fp_100_mortg_value,fp_100_openspace,fp_100_ownerocc,fp_100_ownerocc_value,fp_100_permortg,fp_100_pop,fp_100_rent_burden,fp_100_rent_burden_value,fp_100_resunits,fp_500_area,fp_500_bldg,fp_500_cost_burden,fp_500_cost_burden_value,fp_500_mhhi,fp_500_mortg_value,fp_500_openspace,fp_500_ownerocc,fp_500_ownerocc_value,fp_500_permortg,fp_500_pop,fp_500_rent_burden,fp_500_rent_burden_value,fp_500_resunits,lep_rate,lep_rate_boro,lep_rate_nyc,lot_area_commercial_office,lot_area_industrial_manufacturing,lot_area_mixed_use,lot_area_open_space,lot_area_other_no_data,lot_area_parking,lot_area_public_facility_institution,lot_area_res_1_2_family_bldg,lot_area_res_multifamily_elevator,lot_area_res_multifamily_walkup,lot_area_transportation_utility,lot_area_vacant,lots_commercial_office,lots_industrial_manufacturing,lots_mixed_use,lots_open_space,lots_other_no_data,lots_parking,lots_public_facility_institution,lots_res_1_2_family_bldg,lots_res_multifamily_elevator,lots_res_multifamily_walkup,lots_total,lots_transportation_utility,lots_vacant,male_10_14,male_15_19,male_20_24,male_25_29,male_30_34,male_35_39,male_40_44,male_45_49,male_5_9,male_50_54,male_55_59,male_60_64,male_65_69,male_70_74,male_75_79,male_80_84,male_85_over,male_under_5,mean_commute,mean_commute_boro,mean_commute_nyc,moe_bach_deg,moe_bach_deg_boro,moe_bach_deg_nyc,moe_foreign_born,moe_hh_rent_burd,moe_hh_rent_burd_boro,moe_hh_rent_burd_nyc,moe_lep_rate,moe_lep_rate_boro,moe_lep_rate_nyc,moe_mean_commute,moe_mean_commute_boro,moe_mean_commute_nyc,moe_over65_rate,moe_over65_rate_boro,moe_over65_rate_nyc,moe_poverty_rate,moe_under18_rate,moe_under18_rate_boro,moe_under18_rate_nyc,moe_unemnployment,moe_unemployment_boro,moe_unemployment_cd,neighborhoods,over65_rate,over65_rate_boro,over65_rate_nyc,pct_asian_nh,pct_bach_deg,pct_bach_deg_boro,pct_bach_deg_nyc,pct_black_nh,pct_clean_strts,pct_clean_strts_boro,pct_clean_strts_nyc,pct_foreign_born,pct_hh_rent_burd,pct_hh_rent_burd_boro,pct_hh_rent_burd_nyc,pct_hispanic,pct_other_nh,pct_served_parks,pct_white_nh,pop_2000,pop_2010,pop_acs,pop_change_00_10,poverty_rate,poverty_rate_boro,poverty_rate_nyc,puma,shared_puma,shared_puma_cd,son_issue_1,son_issue_2,son_issue_3,total_lot_area,under18_rate,under18_rate_boro,under18_rate_nyc,unemployment_boro,unemployment_cd,unemployment_nyc%20FROM%20community_district_profiles&filename=indicators.csv')
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (10,19,20,22,33,36,37,38,39) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# I always get 2 Unnamed rows, so I am dropping them
df = df.drop('Unnamed: 0', axis = 1)
df = df.drop('Unnamed: 0.1', axis = 1)
# making all complaint_types lowercase
df['complaint_type'] = df['complaint_type'].str.lower()
df.head()
# Out:
#    unique_key            created_date             closed_date agency  \
# 0    39888071  08/01/2018 12:00:10 AM  08/01/2018 01:52:46 AM    DHS
# 1    39889166  08/01/2018 12:00:26 AM  08/18/2018 10:46:43 AM    HPD
# 2    39882869  08/01/2018 12:00:54 AM  08/01/2018 12:49:55 AM   NYPD
# 3    39894246  08/01/2018 12:01:00 AM  08/02/2018 10:30:00 PM    DEP
# 4    39881329  08/01/2018 12:01:00 AM  08/05/2018 12:00:00 AM   DSNY
#
#                                          agency_name  \
# 0  Operations Unit - Department of Homeless Services
# 1  Department of Housing Preservation and Develop...
# 2                    New York City Police Department
# 3             Department of Environmental Protection
# 4                           Department of Sanitation
#
#                         complaint_type  \
# 0           homeless person assistance
# 1                          door/window
# 2                  noise - residential
# 3                                noise
# 4  request large bulky item collection
#
#                                      descriptor               location_type  \
# 0                                           NaN                       Other
# 1                                          DOOR        RESIDENTIAL BUILDING
# 2                              Loud Music/Party  Residential Building/House
# 3  Noise: Construction Before/After Hours (NM1)                         NaN
# 4           Request Large Bulky Item Collection                    Sidewalk
#
#   incident_zip      incident_address       street_name cross_street_1  \
# 0        10029  200 EAST  109 STREET  EAST  109 STREET       3 AVENUE
# 1        10031  528 WEST  136 STREET  WEST  136 STREET            NaN
# 2        11216     761 LINCOLN PLACE     LINCOLN PLACE  ROGERS AVENUE
# 3        10010                   NaN               NaN            NaN
# 4        11413     121-28 198 STREET        198 STREET     120 AVENUE
#
#     cross_street_2 intersection_street_1 intersection_street_2  address_type  \
# 0         2 AVENUE                   NaN                   NaN       ADDRESS
# 1              NaN                   NaN                   NaN       ADDRESS
# 2  NOSTRAND AVENUE                   NaN                   NaN       ADDRESS
# 3              NaN              5 AVENUE        EAST 21 STREET  INTERSECTION
# 4       122 AVENUE                   NaN                   NaN       ADDRESS
#
#                   city landmark facility_type  status                due_date  \
# 0             NEW YORK      NaN           NaN  Closed  08/01/2018 01:00:10 AM
# 1             NEW YORK      NaN           NaN  Closed                     NaN
# 2             BROOKLYN      NaN      Precinct  Closed  08/01/2018 08:00:54 AM
# 3             NEW YORK      NaN           NaN  Closed                     NaN
# 4  Springfield Gardens      NaN           NaN  Closed                     NaN
#
#                               resolution_description  \
# 0  The mobile outreach response team offered serv...
# 1  The Department of Housing Preservation and Dev...
# 2  The Police Department responded to the complai...
# 3  The Department of Environmental Protection did...
# 4                                                NaN
#
#   resolution_action_updated_date community_board           bbl    borough  \
# 0         08/01/2018 01:52:46 AM    11 MANHATTAN  1.016560e+09  MANHATTAN
# 1         08/18/2018 10:46:43 AM    09 MANHATTAN  1.019880e+09  MANHATTAN
# 2         08/01/2018 12:49:55 AM     08 BROOKLYN  3.012540e+09   BROOKLYN
# 3         08/02/2018 10:30:00 PM    05 MANHATTAN           NaN  MANHATTAN
# 4         08/05/2018 12:00:00 AM       12 QUEENS  4.126830e+09     QUEENS
#
#    x_coordinate_(state_plane)  y_coordinate_(state_plane)  \
# 0                   1000049.0                    228317.0
# 1                    997239.0                    238074.0
# 2                    997732.0                    183674.0
# 3                    986878.0                    208974.0
# 4                   1053308.0                    190084.0
#
#   open_data_channel_type park_facility_name park_borough vehicle_type  \
# 0                 MOBILE        Unspecified    MANHATTAN          NaN
# 1                  PHONE        Unspecified    MANHATTAN          NaN
# 2                 MOBILE        Unspecified     BROOKLYN          NaN
# 3                  PHONE        Unspecified    MANHATTAN          NaN
# 4                  PHONE        Unspecified       QUEENS          NaN
#
#   taxi_company_borough taxi_pick_up_location bridge_highway_name  \
# 0                  NaN                   NaN                 NaN
# 1                  NaN                   NaN                 NaN
# 2                  NaN                   NaN                 NaN
# 3                  NaN                   NaN                 NaN
# 4                  NaN                   NaN                 NaN
#
#   bridge_highway_direction road_ramp bridge_highway_segment   latitude  \
# 0                      NaN       NaN                    NaN  40.793339
# 1                      NaN       NaN                    NaN  40.820124
# 2                      NaN       NaN                    NaN  40.670809
# 3                      NaN       NaN                    NaN  40.740262
# 4                      NaN       NaN                    NaN  40.688144
#
#    longitude                                 location  borocd
# 0 -73.942942   (40.79333937834769, -73.9429417746998)   111.0
# 1 -73.953071   (40.82012422332215, -73.9530712339799)   109.0
# 2 -73.951399   (40.67080917938279, -73.9513990916184)   308.0
# 3 -73.990517  (40.74026158873342, -73.99051651686905)   105.0
# 4 -73.750990  (40.68814402968042, -73.75098958473612)   412.0

# %%
# recoding borocd on original df dataframe

def recode_borocd_counts(row):
    if row.community_board[0] != 'U':
      if 'MANHATTAN' in row.community_board:
        return '1' + row.community_board[:2]
      elif 'BRONX' in row.community_board:
        return '2' + row.community_board[:2]
      elif 'BROOKLYN' in row.community_board:
        return '3' + row.community_board[:2]
      elif 'QUEENS' in row.community_board:
        return '4' + row.community_board[:2]
      elif 'STATEN ISLAND' in row.community_board:
        return '5' + row.community_board[:2]
    else:
      return 'Invalid borocd'

df['borocd'] = df.apply(recode_borocd_counts, axis=1)

# checking recode
df.head()
# Out:
#    unique_key            created_date             closed_date agency  \
# 0    39888071  08/01/2018 12:00:10 AM  08/01/2018 01:52:46 AM    DHS
# 1    39889166  08/01/2018 12:00:26 AM  08/18/2018 10:46:43 AM    HPD
# 2    39882869  08/01/2018 12:00:54 AM  08/01/2018 12:49:55 AM   NYPD
# 3    39894246  08/01/2018 12:01:00 AM  08/02/2018 10:30:00 PM    DEP
# 4    39881329  08/01/2018 12:01:00 AM  08/05/2018 12:00:00 AM   DSNY
#
#                                          agency_name  \
# 0  Operations Unit - Department of Homeless Services
# 1  Department of Housing Preservation and Develop...
# 2                    New York City Police Department
# 3             Department of Environmental Protection
# 4                           Department of Sanitation
#
#                         complaint_type  \
# 0           homeless person assistance
# 1                          door/window
# 2                  noise - residential
# 3                                noise
# 4  request large bulky item collection
#
#                                      descriptor               location_type  \
# 0                                           NaN                       Other
# 1                                          DOOR        RESIDENTIAL BUILDING
# 2                              Loud Music/Party  Residential Building/House
# 3  Noise: Construction Before/After Hours (NM1)                         NaN
# 4           Request Large Bulky Item Collection                    Sidewalk
#
#   incident_zip      incident_address       street_name cross_street_1  \
# 0        10029  200 EAST  109 STREET  EAST  109 STREET       3 AVENUE
# 1        10031  528 WEST  136 STREET  WEST  136 STREET            NaN
# 2        11216     761 LINCOLN PLACE     LINCOLN PLACE  ROGERS AVENUE
# 3        10010                   NaN               NaN            NaN
# 4        11413     121-28 198 STREET        198 STREET     120 AVENUE
#
#     cross_street_2 intersection_street_1 intersection_street_2  address_type  \
# 0         2 AVENUE                   NaN                   NaN       ADDRESS
# 1              NaN                   NaN                   NaN       ADDRESS
# 2  NOSTRAND AVENUE                   NaN                   NaN       ADDRESS
# 3              NaN              5 AVENUE        EAST 21 STREET  INTERSECTION
# 4       122 AVENUE                   NaN                   NaN       ADDRESS
#
#                   city landmark facility_type  status                due_date  \
# 0             NEW YORK      NaN           NaN  Closed  08/01/2018 01:00:10 AM
# 1             NEW YORK      NaN           NaN  Closed                     NaN
# 2             BROOKLYN      NaN      Precinct  Closed  08/01/2018 08:00:54 AM
# 3             NEW YORK      NaN           NaN  Closed                     NaN
# 4  Springfield Gardens      NaN           NaN  Closed                     NaN
#
#                               resolution_description  \
# 0  The mobile outreach response team offered serv...
# 1  The Department of Housing Preservation and Dev...
# 2  The Police Department responded to the complai...
# 3  The Department of Environmental Protection did...
# 4                                                NaN
#
#   resolution_action_updated_date community_board           bbl    borough  \
# 0         08/01/2018 01:52:46 AM    11 MANHATTAN  1.016560e+09  MANHATTAN
# 1         08/18/2018 10:46:43 AM    09 MANHATTAN  1.019880e+09  MANHATTAN
# 2         08/01/2018 12:49:55 AM     08 BROOKLYN  3.012540e+09   BROOKLYN
# 3         08/02/2018 10:30:00 PM    05 MANHATTAN           NaN  MANHATTAN
# 4         08/05/2018 12:00:00 AM       12 QUEENS  4.126830e+09     QUEENS
#
#    x_coordinate_(state_plane)  y_coordinate_(state_plane)  \
# 0                   1000049.0                    228317.0
# 1                    997239.0                    238074.0
# 2                    997732.0                    183674.0
# 3                    986878.0                    208974.0
# 4                   1053308.0                    190084.0
#
#   open_data_channel_type park_facility_name park_borough vehicle_type  \
# 0                 MOBILE        Unspecified    MANHATTAN          NaN
# 1                  PHONE        Unspecified    MANHATTAN          NaN
# 2                 MOBILE        Unspecified     BROOKLYN          NaN
# 3                  PHONE        Unspecified    MANHATTAN          NaN
# 4                  PHONE        Unspecified       QUEENS          NaN
#
#   taxi_company_borough taxi_pick_up_location bridge_highway_name  \
# 0                  NaN                   NaN                 NaN
# 1                  NaN                   NaN                 NaN
# 2                  NaN                   NaN                 NaN
# 3                  NaN                   NaN                 NaN
# 4                  NaN                   NaN                 NaN
#
#   bridge_highway_direction road_ramp bridge_highway_segment   latitude  \
# 0                      NaN       NaN                    NaN  40.793339
# 1                      NaN       NaN                    NaN  40.820124
# 2                      NaN       NaN                    NaN  40.670809
# 3                      NaN       NaN                    NaN  40.740262
# 4                      NaN       NaN                    NaN  40.688144
#
#    longitude                                 location borocd
# 0 -73.942942   (40.79333937834769, -73.9429417746998)    111
# 1 -73.953071   (40.82012422332215, -73.9530712339799)    109
# 2 -73.951399   (40.67080917938279, -73.9513990916184)    308
# 3 -73.990517  (40.74026158873342, -73.99051651686905)    105
# 4 -73.750990  (40.68814402968042, -73.75098958473612)    412

# %%
# gathering a list of unique values for 311 complaints to see the full list of complaints at my disposal
def unique(complaints): 
  
    # intilize a null list 
    complaint_list = [] 
      
    # traverse for all elements 
    for x in complaints: 
        # check if exists in unique_list or not 
        if x not in complaint_list: 
            complaint_list.append(x) 
    # print list 
    for x in complaint_list: 
        print (x)
          
# driver code 
complaints = df.complaint_type
print("ALL UNIQUE 311 COMPLAINTS") 
unique(complaints)
# Out:
# ALL UNIQUE 311 COMPLAINTS
# homeless person assistance
# door/window
# noise - residential
# noise
# request large bulky item collection
# noise - street/sidewalk
# noise - commercial
# blocked driveway
# street condition
# heat/hot water
# unsanitary condition
# general
# paint/plaster
# plumbing
# benefit card replacement
# illegal parking
# derelict vehicles
# noise - vehicle
# street light condition
# electric
# animal abuse
# water system
# derelict vehicle
# damaged tree
# electronics waste appointment
# taxi report
# consumer complaint
# dirty conditions
# water leak
# curb condition
# food establishment
# traffic signal condition
# non-emergency police matter
# street sign - damaged
# asbestos
# lead
# drinking
# maintenance or facility
# sewer
# street sign - missing
# sidewalk condition
# taxi complaint
# root/sewer/sidewalk condition
# general construction/plumbing
# for hire vehicle complaint
# new tree request
# building/use
# sanitation condition
# mosquitoes
# linknyc
# other enforcement
# dead/dying tree
# found property
# collection truck noise
# missed collection (all materials)
# overflowing litter baskets
# noise - park
# vacant lot
# illegal tree damage
# violation of park rules
# homeless encampment
# question
# air quality
# construction safety enforcement
# safety
# appliance
# flooring/stairs
# cranes and derricks
# vending
# street sign - dangling
# housing options
# broken parking meter
# panhandling
# industrial waste
# beach/pool/sauna complaint
# litter basket / request
# overgrown tree/branches
# dof property - rpie issue
# graffiti
# elevator
# traffic
# borough office
# dpr internal
# dof parking - tax exemption
# hpd literature request
# dof property - payment issue
# highway sign - damaged
# best/site safety
# hazardous materials
# dof property - request copy
# water conservation
# scrie
# water quality
# indoor air quality
# sweeping/missed
# food poisoning
# dof property - reduction issue
# dof property - update account
# housing - low income senior
# derelict bicycle
# public payphone complaint
# indoor sewage
# dof property - owner issue
# scaffold safety
# dof parking - payment issue
# highway condition
# poison ivy
# ferry inquiry
# dof parking - dmv clearance
# special projects inspection team (spit)
# animal in a park
# smoking
# animal facility - no permit
# recycling enforcement
# urinating in public
# electrical
# drie
# dof parking - request status
# bus stop shelter complaint
# forms
# mold
# boilers
# building marshals office
# fire alarm - new system
# taxi compliment
# drug activity
# bike rack condition
# unleashed dog
# school maintenance
# dca / doh new license application request
# fatf
# cooling tower
# oem literature request
# mobile food vendor
# investigations and discipline (iad)
# pet shop
# emergency response team (ert)
# miscellaneous categories
# elder abuse
# ferry permit
# tattooing
# executive inspections
# senior center complaint
# day care
# for hire vehicle report
# sweeping/inadequate
# noise - helicopter
# disorderly youth
# rodent
# unsanitary animal pvt property
# standing water
# advocate-co-opcondo abatement
# dof parking - request copy
# dof property - property value
# outside building
# bus stop shelter placement
# bike/roller/skate chronic
# advocate-personal exemptions
# fire alarm - reinspection
# sustainability enforcement
# quality of life
# ferry complaint
# unsanitary pigeon condition
# advocate - other
# advocate-prop refunds/credits
# plant
# bridge condition
# public toilet
# alzheimer's care
# highway sign - missing
# harboring bees/wasps
# taxpayer advocate inquiry
# posting advertisement
# illegal animal sold
# home delivered meal complaint
# noise - house of worship
# unlicensed dog
# illegal animal kept as pet
# abandoned vehicle
# comments
# home delivered meal - missed delivery
# calorie labeling
# drinking water
# research questions
# advocate-commercial exemptions
# overflowing recycling baskets
# bereavement support group
# facades
# rangehood
# radioactive material
# illegal fireworks
# special natural area district (snad)
# advocate - lien
# unsanitary animal facility
# transportation provider complaint
# window guard
# bottled water
# home care provider complaint
# municipal parking facility
# highway sign - dangling
# case management agency complaint
# electronics waste
# lifeguard
# taxi licensee complaint
# fhv licensee complaint
# animal-abuse
# snow
# tunnel condition
# advocate-property value
# non-residential heat
# special operations
# dispatched taxi complaint
# advocate - rpie
# x-ray machine/equipment
# foam ban enforcement
# forensic engineering
# lost property
# single occupancy bathroom
# missed collection
# green taxi complaint
# green taxi report
# dep street condition

# %%
# printing the head of cddf to see what indicators I have at my disposal
cddf.head()
# Out:
#    the_geom  lots_parking  the_geom_webmercator   acres  \
# 0       NaN            23                   NaN   976.3
# 1       NaN            52                   NaN   865.9
# 2       NaN            57                   NaN  1076.9
# 3       NaN            77                   NaN  1131.6
# 4       NaN            39                   NaN  1005.4
#
#                                          acs_tooltip  \
# 0  American Community Survey 2013-2017 5-Year Est...
# 1  American Community Survey 2013-2017 5-Year Est...
# 2  American Community Survey 2013-2017 5-Year Est...
# 3  American Community Survey 2013-2017 5-Year Est...
# 4  American Community Survey 2013-2017 5-Year Est...
#
#                                        acs_tooltip_2  \
# 0  American Community Survey (ACS) 2013-2017 5-ye...
# 1  American Community Survey (ACS) 2013-2017 5-ye...
# 2  American Community Survey (ACS) 2013-2017 5-ye...
# 3  American Community Survey (ACS) 2013-2017 5-ye...
# 4  American Community Survey (ACS) 2013-2017 5-ye...
#
#                                        acs_tooltip_3  area_sqmi  borocd  \
# 0  2010 Census population counts for floodplain a...        1.5     101
# 1  2010 Census population counts for floodplain a...        1.4     102
# 2  2010 Census population counts for floodplain a...        1.7     103
# 3  2010 Census population counts for floodplain a...        1.8     104
# 4  2010 Census population counts for floodplain a...        1.6     105
#
#                 cb_email                                 cb_website  \
# 0       man01@cb.nyc.gov  www1.nyc.gov/site/manhattancb1/index.page
# 1    bgormley@cb.nyc.gov                    www.nyc.gov/html/mancb2
# 2  info@cb3manhattan.org                    www.nyc.gov/html/mancb3
# 3     jbodine@cb.nyc.gov                           www.nyc.gov/mcb4
# 4         office@cb5.org                                www.cb5.org
#
#                     cd_full_title  cd_short_title  \
# 0  Manhattan Community District 1  Manhattan CD 1
# 1  Manhattan Community District 2  Manhattan CD 2
# 2  Manhattan Community District 3  Manhattan CD 3
# 3  Manhattan Community District 4  Manhattan CD 4
# 4  Manhattan Community District 5  Manhattan CD 5
#
#                                        cd_son_fy2018  cd_tot_bldgs  \
# 0  http://www1.nyc.gov/assets/planning/download/p...          1729
# 1  http://www1.nyc.gov/assets/planning/download/p...          5360
# 2  http://www1.nyc.gov/assets/planning/download/p...          4680
# 3  http://www1.nyc.gov/assets/planning/download/p...          3925
# 4  http://www1.nyc.gov/assets/planning/download/p...          3207
#
#    cd_tot_resunits  count_hosp_clinic  count_libraries  count_parks  \
# 0            39547                  7                1           28
# 1            60146                 14                4           16
# 2            79856                 34                5           39
# 3            85030                 25                2           23
# 4            45268                 17                7           10
#
#    count_public_schools  crime_count  crime_count_boro  crime_count_nyc  \
# 0                    22         1099             25961            96515
# 1                    11         2353             25961            96515
# 2                    46         2375             25961            96515
# 3                    30         2462             25961            96515
# 4                    15         4600             25961            96515
#
#    crime_per_1000  crime_per_1000_boro  crime_per_1000_nyc  female_10_14  \
# 0       15.634252                 15.7                11.8           1.1
# 1       25.876288                 15.7                11.8           1.1
# 2       14.953955                 15.7                11.8           1.5
# 3       20.731942                 15.7                11.8           1.1
# 4       87.226379                 15.7                11.8           1.1
#
#    female_15_19  female_20_24  female_25_29  female_30_34  female_35_39  \
# 0           2.4           4.2           7.3           6.6           4.7
# 1           2.4           4.2           7.3           6.6           4.7
# 2           3.0           3.8           6.3           4.4           3.5
# 3           1.7           4.4           7.4           6.1           3.7
# 4           1.7           4.4           7.4           6.1           3.7
#
#    female_40_44  female_45_49  female_5_9  female_50_54  female_55_59  \
# 0           3.5           2.9         1.8           2.2           2.3
# 1           3.5           2.9         1.8           2.2           2.3
# 2           2.9           3.2         1.2           2.9           3.0
# 3           2.8           2.5         0.9           2.5           2.8
# 4           2.8           2.5         0.9           2.5           2.8
#
#    female_60_64  female_65_69  female_70_74  female_75_79  female_80_84  \
# 0           2.5           2.3           1.7           1.0           0.7
# 1           2.5           2.3           1.7           1.0           0.7
# 2           3.5           2.8           2.2           1.7           1.4
# 3           2.6           2.2           1.9           1.4           0.7
# 4           2.6           2.2           1.9           1.4           0.7
#
#    female_85_over  female_under_5  fp_100_area  fp_100_bldg  \
# 0             1.1             2.6         1.78          678
# 1             1.1             2.6         0.25          346
# 2             2.0             1.6         0.53          495
# 3             0.9             1.7         0.57          377
# 4             0.9             1.7         0.00            0
#
#    fp_100_cost_burden  fp_100_cost_burden_value  fp_100_mhhi  \
# 0            0.284774                      2164     121000.0
# 1            0.284774                      2164     121000.0
# 2            0.155306                       360      18000.0
# 3            0.244212                       327     105000.0
# 4            0.000000                       327          NaN
#
#    fp_100_mortg_value  fp_100_openspace  fp_100_ownerocc  \
# 0                4900             0.041         0.220593
# 1                4900             0.001         0.220593
# 2                 932             0.121         0.111997
# 3                 907             0.007         0.086037
# 4                 907             0.000         0.000000
#
#    fp_100_ownerocc_value  fp_100_permortg  fp_100_pop  fp_100_rent_burden  \
# 0                   7599         0.644822       16733            0.353232
# 1                   7599         0.644822        5038            0.353232
# 2                   2318         0.402071       32294            0.463410
# 3                   1339         0.677371        2957            0.423210
# 4                   1339         0.000000           0            0.000000
#
#    fp_100_rent_burden_value  fp_100_resunits  fp_500_area  fp_500_bldg  \
# 0                      7367            19061         2.53         1036
# 1                      7367             4490         0.39          777
# 2                      8169            21052         0.94          819
# 3                      5007            10209         0.86          600
# 4                      5007                0         0.00            0
#
#    fp_500_cost_burden  fp_500_cost_burden_value  fp_500_mhhi  \
# 0            0.284528                      2913     118000.0
# 1            0.284528                      2913     118000.0
# 2            0.161082                       500      21000.0
# 3            0.246237                       458     103000.0
# 4            0.000000                       458          NaN
#
#    fp_500_mortg_value  fp_500_openspace  fp_500_ownerocc  \
# 0                6272             0.042         0.241982
# 1                6272             0.001         0.241982
# 2                1315             0.149         0.106891
# 3                1229             0.022         0.101806
# 4                1229             0.000         0.000000
#
#    fp_500_ownerocc_value  fp_500_permortg  fp_500_pop  fp_500_rent_burden  \
# 0                  10238         0.612620       29221            0.350056
# 1                  10238         0.612620       10198            0.350056
# 2                   3104         0.423647       47273            0.458434
# 3                   1860         0.660753        9609            0.434897
# 4                   1860         0.000000           0            0.000000
#
#    fp_500_rent_burden_value  fp_500_resunits  lep_rate  lep_rate_boro  \
# 0                      8750            28097       5.8           15.5
# 1                      8750             7620       5.8           15.5
# 2                     11382            27544      29.4           15.5
# 3                      5962            17213       9.6           15.5
# 4                      5962                0       9.6           15.5
#
#    lep_rate_nyc  lot_area_commercial_office  \
# 0          23.1                     7865158
# 1          23.1                     4350553
# 2          23.1                     1262797
# 3          23.1                     5177424
# 4          23.1                    18157447
#
#    lot_area_industrial_manufacturing  lot_area_mixed_use  lot_area_open_space  \
# 0                             252207             4271043              1453796
# 1                             644242             6288962               846180
# 2                             370317             8706820              5568872
# 3                            1210626             6805740               827018
# 4                             679097             3906443               428912
#
#    lot_area_other_no_data  lot_area_parking  \
# 0                 5345624            433550
# 1                  132080            347473
# 2                   34365            316724
# 3                   32816           1122007
# 4                   61079            279838
#
#    lot_area_public_facility_institution  lot_area_res_1_2_family_bldg  \
# 0                              10274554                         45535
# 1                               2232810                       1025372
# 2                               3504544                         95111
# 3                               3839650                        278552
# 4                               1842831                         24484
#
#    lot_area_res_multifamily_elevator  lot_area_res_multifamily_walkup  \
# 0                            1746495                           185913
# 1                            3485056                          2420855
# 2                            7995555                          2696581
# 3                            4765298                          2503410
# 4                            1534501                           191188
#
#    lot_area_transportation_utility  lot_area_vacant  lots_commercial_office  \
# 0                          4107387           134060                     343
# 1                          2731028          1191821                     558
# 2                          1562428          1577938                     278
# 3                          9145958          2468769                     430
# 4                           803564           283238                    1565
#
#    lots_industrial_manufacturing  lots_mixed_use  lots_open_space  \
# 0                             78             578               25
# 1                            115            1703               28
# 2                            103            2024              124
# 3                            126             983               21
# 4                            134             730                6
#
#    lots_other_no_data  cartodb_id  lots_public_facility_institution  \
# 0                  11           1                                69
# 1                  17           2                               174
# 2                   6           3                               277
# 3                   6           4                               166
# 4                   8           5                               112
#
#    lots_res_1_2_family_bldg  lots_res_multifamily_elevator  \
# 0                        33                            167
# 1                       623                            442
# 2                        65                            254
# 3                       161                            313
# 4                        15                            187
#
#    lots_res_multifamily_walkup  lots_total  lots_transportation_utility  \
# 0                           65        1448                           33
# 1                          924        4699                           23
# 2                          928        4234                           30
# 3                          961        3410                           89
# 4                           77        2982                           22
#
#    lots_vacant  male_10_14  male_15_19  male_20_24  male_25_29  male_30_34  \
# 0           23         1.4         1.9         2.5         6.0         6.7
# 1           40         1.4         1.9         2.5         6.0         6.7
# 2           88         1.7         2.6         3.7         6.5         5.5
# 3           77         0.6         1.0         3.7         7.0         7.7
# 4           87         0.6         1.0         3.7         7.0         7.7
#
#    male_35_39  male_40_44  male_45_49  male_5_9  male_50_54  male_55_59  \
# 0         5.7         3.7         3.3       1.7         2.8         2.5
# 1         5.7         3.7         3.3       1.7         2.8         2.5
# 2         4.2         3.0         3.3       1.8         3.1         2.7
# 3         5.0         5.2         3.9       1.3         3.6         3.6
# 4         5.0         5.2         3.9       1.3         3.6         3.6
#
#    male_60_64  male_65_69  male_70_74  male_75_79  male_80_84  male_85_over  \
# 0         2.7         1.9         1.2         0.8         0.7           0.7
# 1         2.7         1.9         1.2         0.8         0.7           0.7
# 2         2.5         2.0         1.9         1.1         1.0           0.9
# 3         3.0         2.4         1.3         1.1         0.6           0.4
# 4         3.0         2.4         1.3         1.1         0.6           0.4
#
#    male_under_5  mean_commute  mean_commute_boro  mean_commute_nyc  \
# 0           2.9          25.2               31.8              40.8
# 1           2.9          25.2               31.8              40.8
# 2           1.6          31.5               31.8              40.8
# 3           1.5          26.6               31.8              40.8
# 4           1.5          26.6               31.8              40.8
#
#    moe_bach_deg  moe_bach_deg_boro  moe_bach_deg_nyc  moe_foreign_born  \
# 0           1.0                0.3               0.2               1.1
# 1           1.0                0.3               0.2               1.1
# 2           1.4                0.3               0.2               1.2
# 3           1.2                0.3               0.2               1.1
# 4           1.2                0.3               0.2               1.1
#
#    moe_hh_rent_burd  moe_hh_rent_burd_boro  moe_hh_rent_burd_nyc  \
# 0               1.6                    0.5                   0.3
# 1               1.6                    0.5                   0.3
# 2               1.7                    0.5                   0.3
# 3               1.8                    0.5                   0.3
# 4               1.8                    0.5                   0.3
#
#    moe_lep_rate  moe_lep_rate_boro  moe_lep_rate_nyc  moe_mean_commute  \
# 0           0.6                0.3               0.1               0.5
# 1           0.6                0.3               0.1               0.5
# 2           1.3                0.3               0.1               0.8
# 3           0.8                0.3               0.1               0.5
# 4           0.8                0.3               0.1               0.5
#
#    moe_mean_commute_boro  moe_mean_commute_nyc  moe_over65_rate  \
# 0                    0.2                   0.1              0.7
# 1                    0.2                   0.1              0.7
# 2                    0.2                   0.1              0.7
# 3                    0.2                   0.1              0.6
# 4                    0.2                   0.1              0.6
#
#    moe_over65_rate_boro  moe_over65_rate_nyc  moe_poverty_rate  \
# 0                   0.1                  0.1               0.7
# 1                   0.1                  0.1               0.7
# 2                   0.1                  0.1               1.1
# 3                   0.1                  0.1               0.8
# 4                   0.1                  0.1               0.8
#
#    moe_under18_rate  moe_under18_rate_boro  moe_under18_rate_nyc  \
# 0               0.6                    0.1                   0.1
# 1               0.6                    0.1                   0.1
# 2               0.7                    0.1                   0.1
# 3               0.8                    0.1                   0.1
# 4               0.8                    0.1                   0.1
#
#    moe_unemnployment  moe_unemployment_boro  moe_unemployment_cd  \
# 0                0.1                    0.2                  0.3
# 1                0.1                    0.2                  0.3
# 2                0.1                    0.2                  0.5
# 3                0.1                    0.2                  0.5
# 4                0.1                    0.2                  0.5
#
#                                        neighborhoods  over65_rate  \
# 0  Battery Park City, Civic Center, Ellis Island,...         12.2
# 1  Greenwich Village, Hudson Square, Little Italy...         12.2
# 2  Chinatown, East Village, Lower East Side, NoHo...         17.0
# 3                     Chelsea, Clinton, Hudson Yards         12.9
# 4  Flatiron, Gramercy Park, Herald Square, Midtow...         12.9
#
#    over65_rate_boro  over65_rate_nyc  pct_asian_nh  pct_bach_deg  \
# 0              15.3             13.6          15.7          82.3
# 1              15.3             13.6          15.7          82.3
# 2              15.3             13.6          32.1          43.0
# 3              15.3             13.6          16.6          74.4
# 4              15.3             13.6          16.6          74.4
#
#    pct_bach_deg_boro  pct_bach_deg_nyc  pct_black_nh  pct_clean_strts  \
# 0               60.7              36.7           2.3             95.4
# 1               60.7              36.7           2.3             96.3
# 2               60.7              36.7           7.4             91.0
# 3               60.7              36.7           6.0             95.6
# 4               60.7              36.7           6.0             94.4
#
#    pct_clean_strts_boro  pct_clean_strts_nyc  pct_foreign_born  \
# 0                  94.1                 95.1              23.9
# 1                  94.1                 95.1              23.9
# 2                  94.1                 95.1              34.9
# 3                  94.1                 95.1              29.4
# 4                  94.1                 95.1              29.4
#
#    pct_hh_rent_burd  pct_hh_rent_burd_boro  pct_hh_rent_burd_nyc  \
# 0              31.0                   36.9                  44.5
# 1              31.0                   36.9                  44.5
# 2              38.5                   36.9                  44.5
# 3              33.8                   36.9                  44.5
# 4              33.8                   36.9                  44.5
#
#    pct_hispanic  pct_other_nh  pct_served_parks  pct_white_nh  pop_2000  \
# 0           6.4           3.2               100          72.0     34420
# 1           6.4           3.2               100          72.0     93119
# 2          25.1           3.1               100          32.7    164407
# 3          15.1           2.8                94          59.3     87479
# 4          15.1           2.8                95          59.3     44028
#
#    pop_2010   pop_acs  pop_change_00_10  poverty_rate  poverty_rate_boro  \
# 0     60978       NaN              0.77           8.8               14.4
# 1     90016       NaN             -0.03           8.8               14.4
# 2    163277  159652.0             -0.01          19.3               14.4
# 3    103245       NaN              0.18          11.3               14.4
# 4     51673       NaN              0.17          11.3               14.4
#
#    poverty_rate_nyc  puma  shared_puma  shared_puma_cd         son_issue_1  \
# 0              19.8  3810         True  Manhattan CD 2          Resiliency
# 1              19.8  3810         True  Manhattan CD 1  Affordable housing
# 2              19.8  3809        False             NaN  Affordable housing
# 3              19.8  3807         True  Manhattan CD 5  Affordable housing
# 4              19.8  3807         True  Manhattan CD 4  Affordable housing
#
#                                          son_issue_2  \
# 0                                            Traffic
# 1                                              Parks
# 2                                    Senior services
# 3     Neighborhood preservation (development trends)
# 4  Social services (including services for the ho...
#
#                  son_issue_3  total_lot_area  under18_rate  under18_rate_boro  \
# 0                      Other        36115322          12.8               14.5
# 1                    Schools        25696432          12.8               14.5
# 2                      Other        33692052          11.7               14.5
# 3                    Traffic        38177268           8.2               14.5
# 4  Transit (buses & subways)        28192622           8.2               14.5
#
#    under18_rate_nyc  unemployment_boro  unemployment_cd  unemployment_nyc
# 0                21                4.2              2.8               4.9
# 1                21                4.2              2.8               4.9
# 2                21                4.2              4.1               4.9
# 3                21                4.2              3.7               4.9
# 4                21                4.2              3.7               4.9

# %% [markdown]
# # Step 1.
# Select an indicator from the Community District Profiles data that you want to analyze for this assignment. Create a dataframe that only captures the borocd and selected indicator column.

# %%
print("\033[1;32;43m I want to answer, 'How does the community poverty rate correlate with 311 homeless person assistance?'\n")
print("The complaint type is 'homeless person assistance' and the indicator is 'poverty_rate' \n")
# Out:
#  I want to answer, 'How does the community poverty rate correlate with 311 homeless person assistance?'
#
# The complaint type is 'homeless person assistance' and the indicator is 'poverty_rate'

# %%
cddf_pov = cddf[['borocd','poverty_rate']]
cddf_pov.head()
# Out:
#    borocd  poverty_rate
# 0     101           8.8
# 1     102           8.8
# 2     103          19.3
# 3     104          11.3
# 4     105          11.3

# %% [markdown]
# # Step 2.
# Review the complaint types in the 311 complaint data. Choose the complaint type(s) you hypothesize should correlate with the indicator you chose in Step 2. Create a new dataframe that only captures the 311 complaints you want to analyze.

# %%
df = df[df.complaint_type == "homeless person assistance"]
df_comp = df[['borocd','complaint_type']].groupby(['borocd','complaint_type']).size().reset_index(name='complaints_by_cd')
df_comp.head()
# Out:
#   borocd              complaint_type  complaints_by_cd
# 0    101  homeless person assistance               758
# 1    102  homeless person assistance               965
# 2    103  homeless person assistance               520
# 3    104  homeless person assistance              1055
# 4    105  homeless person assistance              3020

# %% [markdown]
# # Step 3.
# Write out the hypothesis for your analysis. What relationship are you expecting to find between the variables and why?

# %%
print("\033[1;32;43mI expect to see a positive correlation between the variables.\n") 
print("\033[1;32;43mSpecifically, as poverty rate in the Indicators dataset increases, the complaints for homeless person assistance rate will increase\n")
print("\033[1;32;43m(because there will be more homeless people as the poverty rate increases). \n")
# Out:
# I expect to see a positive correlation between the variables.
#
# Specifically, as poverty rate in the Indicators dataset increases, the complaints for homeless person assistance rate will increase
#
# (because there will be more homeless people as the poverty rate increases).

# %% [markdown]
# # Step 4.
# Get the count of 311 complaints per community district (borocd) using the filtered dataframe you created in Step 2.

# %%
df_comp['borocd'] = df_comp['borocd'].astype(int)
df_comp['complaints_by_cd'] = df_comp['complaints_by_cd'].astype(int)
df_comp.head()
# Out:
#    borocd              complaint_type  complaints_by_cd
# 0     101  homeless person assistance               758
# 1     102  homeless person assistance               965
# 2     103  homeless person assistance               520
# 3     104  homeless person assistance              1055
# 4     105  homeless person assistance              3020

# %% [markdown]
# # Step 5.
# Join the indicator dataframe (from Step 1) with 311 counts dataframe (from Step 4) using the borocd value.

# %%
homeless = pd.merge(left=df_comp, right=cddf_pov, left_on=['borocd'], right_on=['borocd'])
homeless.head()
# Out:
#    borocd              complaint_type  complaints_by_cd  poverty_rate
# 0     101  homeless person assistance               758           8.8
# 1     102  homeless person assistance               965           8.8
# 2     103  homeless person assistance               520          19.3
# 3     104  homeless person assistance              1055          11.3
# 4     105  homeless person assistance              3020          11.3

# %% [markdown]
# # Step 6.
# Produce a scatter plot of the indicator values vs. 311 complaint counts. The should be one point per community district.
#
# *Note: I experimented with adding labels.*

# %%
plt.figure(figsize=(15, 6))

boro = homeless.borocd
x_coords = np.array(homeless.poverty_rate) # x
y_coords = np.array(homeless.complaints_by_cd) # y

for i,type in enumerate(boro):
    x = x_coords[i]
    y = y_coords[i]
    plt.scatter(x, y,)
    plt.text(x+0.4, y+0.4, type, fontsize=9)

plt.scatter(
    x_coords,
    y_coords,
    s=50, # size of marker
    alpha=0.5) # transparency. 0 is 100% transparent. 1 is 100% opaque

plt.title('Poverty Rate vs. 311 Homeless Person Assistance Complaints')
plt.xlabel('Community District Poverty Rate')
plt.ylabel('# of Homeless Person Assistance Requests per Community District')

plt.show()

# %% [markdown]
# # Trying again without the community district labels

# %%
plt.figure(figsize=(15, 6))

plt.scatter(
    np.array(homeless.poverty_rate), # x
    np.array(homeless.complaints_by_cd), # y
    s=50, # size of marker
    edgecolors='orange', # outline color of the marker
    c="pink", # color hex color picker: https://www.google.com/search?q=color+picker
    alpha=0.7) # transparency. 0 is 100% transparent. 1 is 100% opaque

plt.title('Poverty Rate vs. 311 Homeless Person Assistance Complaints')
plt.xlabel('Community District Poverty Rate')
plt.ylabel('# of Homeless Person Assistance Requests per Community District')

plt.show()

# %% [markdown]
# # Step 7.
# Conduct an OLS linear regression using the indicator values vs. 311 complaint counts and interpret the results.

# %%
import statsmodels.api as sm

# %%
# determine the correlation coefficient using the np.corrcoef() function from numpy

x = np.array(homeless.poverty_rate)
y = np.array(homeless.complaints_by_cd)

# produces a matrix of the correlation coefficients
np.corrcoef(x, y)
# Out:
# array([[ 1.        , -0.44875844],
#        [-0.44875844,  1.        ]])

# %%
# Note that y is the first argument, before x. This is different than plotting and the correlation function.

# y = dependent variable (# of 311 requests)
y = np.array(homeless.complaints_by_cd)

# x = independent variable (population) with a constant added
x = np.array(homeless.poverty_rate)
x = sm.add_constant(x)

# print(x)

model = sm.OLS(y, x).fit()

# Print out the statistics

print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.201
# Model:                            OLS   Adj. R-squared:                  0.187
# Method:                 Least Squares   F-statistic:                     14.37
# Date:                Fri, 13 Dec 2019   Prob (F-statistic):           0.000364
# Time:                        19:03:58   Log-Likelihood:                -439.31
# No. Observations:                  59   AIC:                             882.6
# Df Residuals:                      57   BIC:                             886.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        892.3524    170.838      5.223      0.000     550.254    1234.450
# x1           -30.7580      8.113     -3.791      0.000     -47.004     -14.512
# ==============================================================================
# Omnibus:                       80.449   Durbin-Watson:                   1.322
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1080.738
# Skew:                           3.797   Prob(JB):                    2.09e-235
# Kurtosis:                      22.544   Cond. No.                         65.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # Step 8.
# Use the linear regression results to add a line of best fit to your scatterplot

# %%
p = model.params # intercept and coefficient
print('parameters:', p)

r2 = model.rsquared
print('R2:', r2)
# Out:
# parameters: [892.35239151 -30.75800348]
# R2: 0.20138414144441885

# %%
label = 'y = ' + str(round(p[1],2)) + 'x + ' + str(round(p[0],2)) + '; R2 = ' + str(round(r2,3))
print(label)
# Out:
# y = -30.76x + 892.35; R2 = 0.201

# %%
x_dummy = np.array(homeless.poverty_rate)

plt.figure(figsize=(15, 6))

plt.scatter(
    np.array(homeless.poverty_rate), # x
    np.array(homeless.complaints_by_cd), # y
    s=50,
    c='#3d03fc',
    alpha=0.5) 

plt.plot(
    x_dummy, 
    p[0] + p[1] * x_dummy,
    c='blue',
    label=label)

plt.title('Poverty Rate vs. 311 Homeless Person Assistance Complaints')
plt.xlabel('Community District Poverty Rate')
plt.ylabel('# of Homeless Person Assistance Requests per Community District')
plt.legend()

plt.show()

# %% [markdown]
# # Step 9.
# Write a paragraph explaining the results of your analysis? Have you found a meaningful relationship?

# %% [markdown]
# *Unfortunately, my regression analysis neither confirmed my hypothesis nor did it provide us with any statistically-signficant results. Contrary to my hypothesis, this analysis illustrates a negative relationship between poverty rates and increased homeless person assistance requests. If I think a bit more deeply about this, one possible explanation for this relationship is that homeless individuals may become "wallpaper" (be overly represented) in high-poverty neighborhoods. Therefore, residents of those high-poverty neighborhoods may be desensitized to their presence and be less likely to call for assistance. However, as mentioned, our OLS regression is not stastically-significant, so even this hypothesis is unlikely to capture the full story behind this relationship.*
